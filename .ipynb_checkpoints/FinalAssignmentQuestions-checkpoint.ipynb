# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
'''
- 1. Create a DataFrame containing the following variables: Ticker, Total Assets, 
Number of Employees, Market Capitalization, Total Number of Transactions, Average 
Transaction Value (you will have to merge multiple datasets). 
Make sure you check the shape of your final dataset! (Hint: Duplicates)
'''
SPTSXComposite = pd.read_csv("SPTSXComposite.csv")
SPTSXCap_Employees = pd.read_csv("SPTSXCap_Employees.csv")
SP_Transactions = pd.read_csv("SP_Transactions.csv")

# %%
SPTSXComposite
# Out:
#                                                   Name        Ticker  \
# 0                Agnico Eagle Mines Limited (NYSE:AEM)      NYSE:AEM
# 1                                  Air Canada (TSX:AC)        TSX:AC
# 2                           Alamos Gold Inc. (TSX:AGI)       TSX:AGI
# 3          Algonquin Power & Utilities Corp. (TSX:AQN)       TSX:AQN
# 4            Alimentation Couche-Tard Inc. (TSX:ATD.B)     TSX:ATD.B
# 5    Allied Properties Real Estate Investment Trust...     TSX:AP.UN
# 6                               AltaGas Ltd. (TSX:ALA)       TSX:ALA
# 7                                ATCO Ltd. (TSX:ACO.X)     TSX:ACO.X
# 8                       Aurora Cannabis Inc. (TSX:ACB)       TSX:ACB
# 9                               B2Gold Corp. (TSX:BTO)       TSX:BTO
# 10                          Bank of Montreal (TSX:BMO)       TSX:BMO
# 11                  Barrick Gold Corporation (TSX:ABX)       TSX:ABX
# 12             Bausch Health Companies Inc. (NYSE:BHC)      NYSE:BHC
# 13                                  BCE Inc. (TSX:BCE)       TSX:BCE
# 14                         BlackBerry Limited (TSX:BB)        TSX:BB
# 15                         Bombardier Inc. (TSX:BBD.B)     TSX:BBD.B
# 16                 Boyd Group Income Fund (TSX:BYD.UN)    TSX:BYD.UN
# 17        Brookfield Asset Management Inc. (TSX:BAM.A)     TSX:BAM.A
# 18        Brookfield Business Partners L.P. (NYSE:BBU)      NYSE:BBU
# 19   Brookfield Infrastructure Partners L.P. (NYSE:...      NYSE:BIP
# 20    Brookfield Property Partners L.P. (NasdaqGS:BPY)  NasdaqGS:BPY
# 21     Brookfield Renewable Partners L.P. (TSX:BEP.UN)    TSX:BEP.UN
# 22                                  BRP Inc. (TSX:DOO)       TSX:DOO
# 23                                  CAE Inc. (TSX:CAE)       TSX:CAE
# 24                        Cameco Corporation (TSX:CCO)       TSX:CCO
# 25               Canada Goose Holdings Inc. (TSX:GOOS)      TSX:GOOS
# 26   Canadian Apartment Properties Real Estate Inve...    TSX:CAR.UN
# 27         Canadian Imperial Bank of Commerce (TSX:CM)        TSX:CM
# 28         Canadian National Railway Company (TSX:CNR)       TSX:CNR
# 29        Canadian Natural Resources Limited (TSX:CNQ)       TSX:CNQ
# ..                                                 ...           ...
# 102                              Saputo Inc. (TSX:SAP)       TSX:SAP
# 103               Shaw Communications Inc. (TSX:SJR.B)     TSX:SJR.B
# 104                           Shopify Inc. (NYSE:SHOP)     NYSE:SHOP
# 105  SmartCentres Real Estate Investment Trust (TSX...    TSX:SRU.UN
# 106                   SNC-Lavalin Group Inc. (TSX:SNC)       TSX:SNC
# 107                        Spin Master Corp. (TSX:TOY)       TSX:TOY
# 108                             Stantec Inc. (TSX:STN)       TSX:STN
# 109                         Stella-Jones Inc. (TSX:SJ)        TSX:SJ
# 110                  Sun Life Financial Inc. (TSX:SLF)       TSX:SLF
# 111                        Suncor Energy Inc. (TSX:SU)        TSX:SU
# 112                    TC Energy Corporation (TSX:TRP)       TSX:TRP
# 113                Teck Resources Limited (TSX:TECK.B)    TSX:TECK.B
# 114                          TELUS Corporation (TSX:T)         TSX:T
# 115                  TFI International Inc. (TSX:TFII)      TSX:TFII
# 116                  The Bank of Nova Scotia (TSX:BNS)       TSX:BNS
# 117          The Descartes Systems Group Inc (TSX:DSG)       TSX:DSG
# 118                    The Stars Group Inc. (TSX:TSGI)      TSX:TSGI
# 119                 The Toronto-Dominion Bank (TSX:TD)        TSX:TD
# 120              Thomson Reuters Corporation (TSX:TRI)       TSX:TRI
# 121                          TMX Group Limited (TSX:X)         TSX:X
# 122                 Toromont Industries Ltd. (TSX:TIH)       TSX:TIH
# 123                     Tourmaline Oil Corp. (TSX:TOU)       TSX:TOU
# 124                TransAlta Renewables Inc. (TSX:RNW)       TSX:RNW
# 125                    Vermilion Energy Inc. (TSX:VET)       TSX:VET
# 126                 Waste Connections, Inc. (NYSE:WCN)      NYSE:WCN
# 127              West Fraser Timber Co. Ltd. (TSX:WFT)       TSX:WFT
# 128                    WestJet Airlines Ltd. (TSX:WJA)       TSX:WJA
# 129            Wheaton Precious Metals Corp. (TSX:WPM)       TSX:WPM
# 130                          WSP Global Inc. (TSX:WSP)       TSX:WSP
# 131                         Yamana Gold Inc. (TSX:YRI)       TSX:YRI
#
#      TotalAssets  TotalRevenue  GeographicSegments           PrimarySector
# 0        10715.5        2990.0                 5.0               Materials
# 1        19197.0       18065.0                 5.0             Industrials
# 2         4455.5         889.4                 4.0               Materials
# 3        12811.6        2247.9                 2.0               Utilities
# 4        30426.3       79562.8                 3.0        Consumer Staples
# 5         6706.3         436.4                 1.0             Real Estate
# 6        23487.7        4256.7                 2.0               Utilities
# 7        23344.0        4888.0                 3.0               Utilities
# 8         1910.7          55.2                 3.0             Health Care
# 9         3476.6        1671.6                 9.0               Materials
# 10      774048.0       22375.0                 3.0              Financials
# 11       30880.9        9883.4                12.0               Materials
# 12       44336.6       11434.8                17.0             Health Care
# 13       57100.0       23468.0                 1.0  Communication Services
# 14        5173.3        1190.3                 7.0  Information Technology
# 15       34056.2       22154.7                13.0             Industrials
# 16        1233.5        1864.6                 2.0             Industrials
# 17      349705.7       79975.7                 9.0              Financials
# 18       37276.5       50717.2                 8.0             Industrials
# 19       49914.9        6347.8                11.0               Utilities
# 20      167183.4       11170.1                 9.0             Real Estate
# 21       46534.9        4069.1                 6.0               Utilities
# 22        3077.2        5243.8                10.0  Consumer Discretionary
# 23        7165.5        3304.1                15.0             Industrials
# 24        8018.6        2091.7                 6.0                  Energy
# 25         725.4         830.5                 3.0  Consumer Discretionary
# 26       10842.3         688.6                 9.0             Real Estate
# 27      597099.0       16964.0                 4.0              Financials
# 28       41214.0       14321.0                 2.0             Industrials
# 29       71559.0       21027.0                 NaN                  Energy
# ..           ...           ...                 ...                     ...
# 102       9885.6       13501.9                 5.0        Consumer Staples
# 103      14424.0        5239.0                 1.0  Communication Services
# 104       3076.7        1464.5                 5.0  Information Technology
# 105       9459.6         811.1                 1.0             Real Estate
# 106      12939.7       10084.0                11.0             Industrials
# 107       1426.5        2226.3                 8.0  Consumer Discretionary
# 108       4009.9        3355.2                 4.0             Industrials
# 109       2062.2        2123.9                 2.0               Materials
# 110     271827.0       26997.0                 NaN              Financials
# 111      89579.0       38542.0                 3.0                  Energy
# 112      98920.0       13679.0                 3.0                  Energy
# 113      39626.0       12564.0                15.0               Materials
# 114      33065.0       14095.0                 1.0  Communication Services
# 115       4050.0        5123.2                 3.0             Industrials
# 116     998493.0       26164.0                 8.0              Financials
# 117        858.9         361.7                 4.0  Information Technology
# 118      15372.3        2769.0                 8.0  Consumer Discretionary
# 119    1334903.0       36354.0                 3.0              Financials
# 120      23261.3        7506.3                 7.0             Industrials
# 121      31657.9        1014.8                 4.0              Financials
# 122       3234.5        3504.2                 3.0             Industrials
# 123      10732.5        1688.0                 1.0                  Energy
# 124       3747.0         446.0                 1.0               Utilities
# 125       6270.7        1526.0                16.0                  Energy
# 126      17230.5        6717.5                 2.0             Industrials
# 127       4791.0        6118.0                 5.0               Materials
# 128       6758.1        4728.4                 4.0             Industrials
# 129       8828.6        1083.5                 9.0               Materials
# 130       7766.6        7908.1                 8.0             Industrials
# 131      10933.9        2454.1                 5.0               Materials
#
# [132 rows x 6 columns]

# %%
SPTSXCap_Employees
# Out:
#             Ticker                                               Name  \
# 0         NYSE:AEM              Agnico Eagle Mines Limited (NYSE:AEM)
# 1           TSX:AC                                Air Canada (TSX:AC)
# 2          TSX:AGI                         Alamos Gold Inc. (TSX:AGI)
# 3          TSX:AQN        Algonquin Power & Utilities Corp. (TSX:AQN)
# 4        TSX:ATD.B          Alimentation Couche-Tard Inc. (TSX:ATD.B)
# 5        TSX:AP.UN  Allied Properties Real Estate Investment Trust...
# 6          TSX:ALA                             AltaGas Ltd. (TSX:ALA)
# 7        TSX:ACO.X                              ATCO Ltd. (TSX:ACO.X)
# 8          TSX:ACB                     Aurora Cannabis Inc. (TSX:ACB)
# 9          TSX:BTO                             B2Gold Corp. (TSX:BTO)
# 10         TSX:BMO                         Bank of Montreal (TSX:BMO)
# 11         TSX:ABX                 Barrick Gold Corporation (TSX:ABX)
# 12        NYSE:BHC            Bausch Health Companies Inc. (NYSE:BHC)
# 13         TSX:BCE                                 BCE Inc. (TSX:BCE)
# 14          TSX:BB                        BlackBerry Limited (TSX:BB)
# 15       TSX:BBD.B                        Bombardier Inc. (TSX:BBD.B)
# 16      TSX:BYD.UN                Boyd Group Income Fund (TSX:BYD.UN)
# 17       TSX:BAM.A       Brookfield Asset Management Inc. (TSX:BAM.A)
# 18        NYSE:BBU       Brookfield Business Partners L.P. (NYSE:BBU)
# 19        NYSE:BIP  Brookfield Infrastructure Partners L.P. (NYSE:...
# 20    NasdaqGS:BPY   Brookfield Property Partners L.P. (NasdaqGS:BPY)
# 21      TSX:BEP.UN    Brookfield Renewable Partners L.P. (TSX:BEP.UN)
# 22         TSX:DOO                                 BRP Inc. (TSX:DOO)
# 23         TSX:CAE                                 CAE Inc. (TSX:CAE)
# 24         TSX:CCO                       Cameco Corporation (TSX:CCO)
# 25        TSX:GOOS              Canada Goose Holdings Inc. (TSX:GOOS)
# 26      TSX:CAR.UN  Canadian Apartment Properties Real Estate Inve...
# 27          TSX:CM        Canadian Imperial Bank of Commerce (TSX:CM)
# 28         TSX:CNR        Canadian National Railway Company (TSX:CNR)
# 29         TSX:CNQ       Canadian Natural Resources Limited (TSX:CNQ)
# ..             ...                                                ...
# 112        TSX:TRP                    TC Energy Corporation (TSX:TRP)
# 113     TSX:TECK.B                Teck Resources Limited (TSX:TECK.B)
# 114          TSX:T                          TELUS Corporation (TSX:T)
# 115       TSX:TFII                  TFI International Inc. (TSX:TFII)
# 116        TSX:BNS                  The Bank of Nova Scotia (TSX:BNS)
# 117        TSX:DSG          The Descartes Systems Group Inc (TSX:DSG)
# 118       TSX:TSGI                    The Stars Group Inc. (TSX:TSGI)
# 119         TSX:TD                 The Toronto-Dominion Bank (TSX:TD)
# 120        TSX:TRI              Thomson Reuters Corporation (TSX:TRI)
# 121          TSX:X                          TMX Group Limited (TSX:X)
# 122        TSX:TIH                 Toromont Industries Ltd. (TSX:TIH)
# 123        TSX:TOU                     Tourmaline Oil Corp. (TSX:TOU)
# 124        TSX:RNW                TransAlta Renewables Inc. (TSX:RNW)
# 125        TSX:VET                    Vermilion Energy Inc. (TSX:VET)
# 126       NYSE:WCN                 Waste Connections, Inc. (NYSE:WCN)
# 127        TSX:WFT              West Fraser Timber Co. Ltd. (TSX:WFT)
# 128        TSX:WJA                    WestJet Airlines Ltd. (TSX:WJA)
# 129        TSX:WPM            Wheaton Precious Metals Corp. (TSX:WPM)
# 130        TSX:WSP                          WSP Global Inc. (TSX:WSP)
# 131        TSX:YRI                         Yamana Gold Inc. (TSX:YRI)
# 132        TSX:ACB                     Aurora Cannabis Inc. (TSX:ACB)
# 133        TSX:BTO                             B2Gold Corp. (TSX:BTO)
# 134  NasdaqGS:OTEX              Open Text Corporation (NasdaqGS:OTEX)
# 135       TSX:PAAS               Pan American Silver Corp. (TSX:PAAS)
# 136        TSX:PXT                     Parex Resources Inc. (TSX:PXT)
# 137       TSX:TSGI                    The Stars Group Inc. (TSX:TSGI)
# 138         TSX:TD                 The Toronto-Dominion Bank (TSX:TD)
# 139        TSX:EMA                       Emera Incorporated (TSX:EMA)
# 140      TSX:EMP.A                 Empire Company Limited (TSX:EMP.A)
# 141       TSX:GOOS              Canada Goose Holdings Inc. (TSX:GOOS)
#
#      MarketCapitalization  NumberEmployees
# 0                 15892.5           5990.0
# 1                 11338.6          32600.0
# 2                  3151.9           1700.0
# 3                  8000.0           2277.0
# 4                 47281.4         133000.0
# 5                  5621.8            263.0
# 6                  5512.0           2881.0
# 7                  5042.8           6241.0
# 8                  8958.5            967.0
# 9                  4105.6           3168.0
# 10                63889.1          45454.0
# 11                37685.1          17500.0
# 12                10834.5          21100.0
# 13                54280.8          52790.0
# 14                 5139.5           3945.0
# 15                 5233.7          56920.0
# 16                 3473.0           8568.0
# 17                61229.8         101700.0
# 18                 7560.6          26900.0
# 19                16419.9           6000.0
# 20                10333.7          19000.0
# 21                14574.3           2325.0
# 22                 4689.0          12500.0
# 23                 9683.0          10000.0
# 24                 5723.2           1897.0
# 25                 6254.2           3932.0
# 26                 7813.5            908.0
# 27                45870.7          44797.0
# 28                88154.5          27215.0
# 29                43045.8           9973.0
# ..                    ...              ...
# 112               61337.2           7081.0
# 113               15901.5          10000.0
# 114               29346.7          58000.0
# 115                3241.5          17636.0
# 116               85329.1          99678.0
# 117                4015.2           1356.0
# 118                6113.9           4516.0
# 119              139949.9          87999.0
# 120               43979.9          25800.0
# 121                5191.6           1280.0
# 122                5103.1           6000.0
# 123                4600.4            237.0
# 124                3727.1              NaN
# 125                4419.2            698.0
# 126               33303.5          16356.0
# 127                3758.8           7800.0
# 128                3500.6          11905.0
# 129               14000.9             39.0
# 130                7728.9          49000.0
# 131                3268.9           5165.0
# 132                8958.5            967.0
# 133                4105.6           3168.0
# 134               14905.9          13100.0
# 135                3565.0           4530.0
# 136                3129.7            279.0
# 137                6113.9           4516.0
# 138              139949.9          87999.0
# 139               12873.1           7523.0
# 140                9112.5         123000.0
# 141                6254.2           3932.0
#
# [142 rows x 4 columns]

# %%
SP_Transactions
# Out:
#             Date     Ticker     TransactionType  TransactionValue
# 0     03/08/2016    TSX:AAV     Public Offering             87.54
# 1     11/29/2018   TSX:ADVZ  Shelf Registration            185.40
# 2     09/06/2018   TSX:ADVZ   Private Placement            775.11
# 3     10/06/2016   TSX:ADVZ     Public Offering            462.65
# 4     09/26/2018    TSX:ARE     Public Offering            160.00
# 5     03/07/2018    TSX:AOI  Merger/Acquisition             22.73
# 6     03/19/2019    TSX:AFN     Public Offering             75.00
# 7     10/25/2018    TSX:AFN     Public Offering            100.25
# 8     01/03/2018    TSX:AFN     Public Offering             75.00
# 9     04/25/2017    TSX:AFN     Public Offering             75.00
# 10    02/15/2017    TSX:AFN     Public Offering             60.61
# 11    04/05/2018   NYSE:AEM   Private Placement            447.84
# 12    05/05/2017   NYSE:AEM   Private Placement            411.08
# 13    03/27/2017   NYSE:AEM     Public Offering            294.14
# 14    06/30/2016   NYSE:AEM   Private Placement            454.29
# 15    09/23/2016     TSX:AC     Public Offering            200.00
# 16    05/02/2018    TSX:AKU     Public Offering             44.97
# 17    02/09/2018    TSX:AKU  Merger/Acquisition              2.35
# 18    07/31/2017    TSX:AGI   Private Placement             11.70
# 19    02/09/2017    TSX:AGI     Public Offering            328.41
# 20    02/14/2018   TSX:CLIQ   Private Placement            138.00
# 21    09/29/2016   TSX:CLIQ     Public Offering             67.50
# 22    11/23/2018   TSX:ALEF   Private Placement             10.00
# 23    03/01/2018   TSX:ALEF   Private Placement             30.21
# 24    04/23/2019    TSX:AXR   Private Placement              3.50
# 25    06/13/2018    TSX:AXR     Public Offering              9.04
# 26    05/30/2017    TSX:AXR   Private Placement              9.04
# 27    05/30/2016    TSX:AXR  Merger/Acquisition              0.28
# 28    05/17/2016    TSX:AXR   Private Placement             13.01
# 29    05/16/2019    TSX:AQN     Public Offering            470.33
# ...          ...        ...                 ...               ...
# 4866  06/22/2016   NYSE:WCN  Shelf Registration             10.83
# 4867  06/22/2016   NYSE:WCN  Shelf Registration             19.84
# 4868  06/22/2016   NYSE:WCN  Shelf Registration              7.57
# 4869  04/29/2016    TSX:WDO     Public Offering             15.02
# 4870  09/18/2018    TSX:WFT             Buyback            525.18
# 4871  05/17/2017    TSX:WJA             Buyback             88.31
# 4872  06/13/2016    TSX:WJA     Public Offering            510.06
# 4873  07/19/2017   TSX:WPRT     Public Offering             31.55
# 4874  06/01/2016   TSX:WPRT   Private Placement             35.00
# 4875  03/18/2019    TSX:WTE             Buyback             84.06
# 4876  03/31/2016    TSX:WPM     Public Offering            713.30
# 4877  12/04/2017    TSX:WCP   Private Placement             92.51
# 4878  12/04/2017    TSX:WCP     Public Offering            332.51
# 4879  05/31/2017    TSX:WCP   Private Placement            200.00
# 4880  01/05/2017    TSX:WCP   Private Placement            200.00
# 4881  05/30/2016    TSX:WCP     Public Offering            470.00
# 4882  03/15/2016    TSX:WCP     Public Offering             95.01
# 4883  02/25/2019  TSX:WIR.U     Public Offering            177.90
# 4884  07/18/2017  TSX:WIR.U     Public Offering            115.07
# 4885  07/19/2016  TSX:WIR.U   Private Placement             19.54
# 4886  07/19/2016  TSX:WIR.U     Public Offering             78.16
# 4887  06/02/2016  TSX:WIR.U  Merger/Acquisition             68.67
# 4888  01/20/2016  TSX:WIR.U  Merger/Acquisition             82.47
# 4889  11/29/2017    TSX:YRI     Public Offering            385.61
# 4890  05/25/2016    TSX:YGR     Public Offering             10.00
# 4891  04/02/2019    TSX:ZCL  Merger/Acquisition            322.16
# 4892  06/11/2018   TSX:ZYME  Shelf Registration             33.30
# 4893  06/06/2018   TSX:ZYME     Public Offering            109.83
# 4894  04/27/2017   TSX:ZYME     Public Offering             79.94
# 4895  01/08/2016   TSX:ZYME   Private Placement             86.97
#
# [4896 rows x 4 columns]

# %%
'''
Variables contained in select Dataframes:
SPTSXComposite - Ticker, Total Assets
SPTSXCap_Employees - NumberEmployees, MarketCapitalization
SP_Transactions? - Total Number of Transactions (groupby...), Average Transaction Value
'''
# Get Total Number of Transactions
# TotalNoTransactions = SP_Transactions.groupby(['Ticker']).count() # incorrect
TotalNoTransactions = SP_Transactions.groupby(['Ticker'])['TransactionType'].count()
TotalNoTransactions
# Out:
# Ticker
# AMEX:GTE          4
# NYSE:AEM          4
# NYSE:BHC          9
# NYSE:MUX          5
# NYSE:RBA          2
# NYSE:SHOP         4
# NYSE:WCN         12
# NasdaqGS:OTEX     3
# OTCPK:FFXD.F      2
# OTCPK:FFXX.F      3
# TSX:AAV           1
# TSX:AC            1
# TSX:ACB          14
# TSX:ACI           3
# TSX:ACO.X         1
# TSX:ADVZ          3
# TSX:ADW.A         1
# TSX:AFN           5
# TSX:AGI           2
# TSX:AI            6
# TSX:AII           8
# TSX:AKG           1
# TSX:AKU           2
# TSX:ALA           7
# TSX:ALEF          2
# TSX:ALS           2
# TSX:ALYA          1
# TSX:AOI           1
# TSX:AP.UN         7
# TSX:APHA          7
#                  ..
# TSX:TSGI          3
# TSX:TSU           2
# TSX:TV            2
# TSX:TVE           2
# TSX:TVK           2
# TSX:TWM           4
# TSX:TXG           1
# TSX:U             3
# TSX:UNS           1
# TSX:VB            1
# TSX:VET           1
# TSX:VFF           4
# TSX:VII           3
# TSX:VLE           2
# TSX:WCP           6
# TSX:WDO           1
# TSX:WEED          9
# TSX:WFT           1
# TSX:WIR.U         6
# TSX:WJA           2
# TSX:WPM           1
# TSX:WPRT          2
# TSX:WTE           1
# TSX:X             2
# TSX:XAU           2
# TSX:XTC           1
# TSX:YGR           1
# TSX:YRI           1
# TSX:ZCL           1
# TSX:ZYME          4
# Name: TransactionType, Length: 366, dtype: int64

# %%
# Average Transaction Value
AvgTransactionValue = SP_Transactions.groupby(['Ticker'])['TransactionValue'].mean()
AvgTransactionValue
# Out:
# Ticker
# AMEX:GTE          206.620000
# NYSE:AEM          401.837500
# NYSE:BHC         1452.904444
# NYSE:MUX           35.492000
# NYSE:RBA          331.110000
# NYSE:SHOP         604.657500
# NYSE:WCN          198.457500
# NasdaqGS:OTEX     622.963333
# OTCPK:FFXD.F      329.755000
# OTCPK:FFXX.F      253.196667
# TSX:AAV            87.540000
# TSX:AC            200.000000
# TSX:ACB           106.191429
# TSX:ACI           263.006667
# TSX:ACO.X         200.000000
# TSX:ADVZ          474.386667
# TSX:ADW.A           2.250000
# TSX:AFN            77.172000
# TSX:AGI           170.055000
# TSX:AI             29.176667
# TSX:AII             2.445000
# TSX:AKG            17.660000
# TSX:AKU            23.660000
# TSX:ALA           571.747143
# TSX:ALEF           20.105000
# TSX:ALS            67.505000
# TSX:ALYA           52.810000
# TSX:AOI            22.730000
# TSX:AP.UN         202.182857
# TSX:APHA          137.321429
#                     ...
# TSX:TSGI          972.600000
# TSX:TSU            65.770000
# TSX:TV            138.775000
# TSX:TVE            55.005000
# TSX:TVK            10.220000
# TSX:TWM            79.592500
# TSX:TXG            55.060000
# TSX:U              19.343333
# TSX:UNS            36.340000
# TSX:VB              5.000000
# TSX:VET           402.200000
# TSX:VFF            15.885000
# TSX:VII           604.486667
# TSX:VLE            35.485000
# TSX:WCP           231.671667
# TSX:WDO            15.020000
# TSX:WEED          686.024444
# TSX:WFT           525.180000
# TSX:WIR.U          90.301667
# TSX:WJA           299.185000
# TSX:WPM           713.300000
# TSX:WPRT           33.275000
# TSX:WTE            84.060000
# TSX:X             250.000000
# TSX:XAU            33.320000
# TSX:XTC            10.020000
# TSX:YGR            10.000000
# TSX:YRI           385.610000
# TSX:ZCL           322.160000
# TSX:ZYME           77.510000
# Name: TransactionValue, Length: 366, dtype: float64

# %%
'''
Variables contained in select Dataframes:
SPTSXComposite - Ticker, Total Assets
SPTSXCap_Employees - NumberEmployees, MarketCapitalization - has duplicates
TotalNoTransactions - Total Number of Transactions 
AvgTransactionValue - Average Transaction Value
We now have 2 Dataframes and 2 Series containing the columns we want.
'''
'''
Reiteration of question:
- 1. Create a DataFrame containing the following variables: Ticker, Total Assets, 
Number of Employees, Market Capitalization, Total Number of Transactions, Average 
Transaction Value (you will have to merge multiple datasets). 
Make sure you check the shape of your final dataset! (Hint: Duplicates)
'''
# check for duplicates
# SPTSXCap_Employees.duplicated().any()
SPTSXCap_Employees.loc[SPTSXCap_Employees.duplicated()]
# Out:
#             Ticker                                   Name  \
# 132        TSX:ACB         Aurora Cannabis Inc. (TSX:ACB)
# 133        TSX:BTO                 B2Gold Corp. (TSX:BTO)
# 134  NasdaqGS:OTEX  Open Text Corporation (NasdaqGS:OTEX)
# 135       TSX:PAAS   Pan American Silver Corp. (TSX:PAAS)
# 136        TSX:PXT         Parex Resources Inc. (TSX:PXT)
# 137       TSX:TSGI        The Stars Group Inc. (TSX:TSGI)
# 138         TSX:TD     The Toronto-Dominion Bank (TSX:TD)
# 139        TSX:EMA           Emera Incorporated (TSX:EMA)
# 140      TSX:EMP.A     Empire Company Limited (TSX:EMP.A)
# 141       TSX:GOOS  Canada Goose Holdings Inc. (TSX:GOOS)
#
#      MarketCapitalization  NumberEmployees
# 132                8958.5            967.0
# 133                4105.6           3168.0
# 134               14905.9          13100.0
# 135                3565.0           4530.0
# 136                3129.7            279.0
# 137                6113.9           4516.0
# 138              139949.9          87999.0
# 139               12873.1           7523.0
# 140                9112.5         123000.0
# 141                6254.2           3932.0

# %%
# remove duplicates
SPTSXCap_Employees_no_dup = SPTSXCap_Employees.drop_duplicates(keep='first')
print(SPTSXCap_Employees_no_dup.shape)
# Out:
# (132, 4)

# %%
'''
Variables contained in select Dataframes:
SPTSXComposite - Ticker, Total Assets
SPTSXCap_Employees (now SPTSXCap_Employees_no_dup) - NumberEmployees, MarketCapitalization
TotalNoTransactions - Total Number of Transactions 
AvgTransactionValue - Average Transaction Value
We now have 2 Dataframes and 2 Series containing the columns we want.
'''
'''
Reiteration of question:
- 1. Create a DataFrame containing the following variables: Ticker, Total Assets, 
Number of Employees, Market Capitalization, Total Number of Transactions, Average 
Transaction Value (you will have to merge multiple datasets). 
Make sure you check the shape of your final dataset! (Hint: Duplicates)
'''
# TotalNoTransactions.loc[TotalNoTransactions.duplicated()]
# TotalNoTransactions_no_dup = TotalNoTransactions.drop_duplicates(keep='first')
# print(TotalNoTransactions_no_dup.shape)
# do a left join
# Out:
# '\nReiteration of question:\n- 1. Create a DataFrame containing the following variables: Ticker, Total Assets, \nNumber of Employees, Market Capitalization, Total Number of Transactions, Average \nTransaction Value (you will have to merge multiple datasets). \nMake sure you check the shape of your final dataset! (Hint: Duplicates)\n'

# %%
# combine the first two datasets - SPTSXComposite and SPTSXCap_Employees
SPTSXComposite_and_XCap_Employees = pd.merge(
    SPTSXComposite,SPTSXCap_Employees, on='Ticker', how='left')
SPTSXComposite_and_XCap_Employees
# Out:
#                                                 Name_x        Ticker  \
# 0                Agnico Eagle Mines Limited (NYSE:AEM)      NYSE:AEM
# 1                                  Air Canada (TSX:AC)        TSX:AC
# 2                           Alamos Gold Inc. (TSX:AGI)       TSX:AGI
# 3          Algonquin Power & Utilities Corp. (TSX:AQN)       TSX:AQN
# 4            Alimentation Couche-Tard Inc. (TSX:ATD.B)     TSX:ATD.B
# 5    Allied Properties Real Estate Investment Trust...     TSX:AP.UN
# 6                               AltaGas Ltd. (TSX:ALA)       TSX:ALA
# 7                                ATCO Ltd. (TSX:ACO.X)     TSX:ACO.X
# 8                       Aurora Cannabis Inc. (TSX:ACB)       TSX:ACB
# 9                       Aurora Cannabis Inc. (TSX:ACB)       TSX:ACB
# 10                              B2Gold Corp. (TSX:BTO)       TSX:BTO
# 11                              B2Gold Corp. (TSX:BTO)       TSX:BTO
# 12                          Bank of Montreal (TSX:BMO)       TSX:BMO
# 13                  Barrick Gold Corporation (TSX:ABX)       TSX:ABX
# 14             Bausch Health Companies Inc. (NYSE:BHC)      NYSE:BHC
# 15                                  BCE Inc. (TSX:BCE)       TSX:BCE
# 16                         BlackBerry Limited (TSX:BB)        TSX:BB
# 17                         Bombardier Inc. (TSX:BBD.B)     TSX:BBD.B
# 18                 Boyd Group Income Fund (TSX:BYD.UN)    TSX:BYD.UN
# 19        Brookfield Asset Management Inc. (TSX:BAM.A)     TSX:BAM.A
# 20        Brookfield Business Partners L.P. (NYSE:BBU)      NYSE:BBU
# 21   Brookfield Infrastructure Partners L.P. (NYSE:...      NYSE:BIP
# 22    Brookfield Property Partners L.P. (NasdaqGS:BPY)  NasdaqGS:BPY
# 23     Brookfield Renewable Partners L.P. (TSX:BEP.UN)    TSX:BEP.UN
# 24                                  BRP Inc. (TSX:DOO)       TSX:DOO
# 25                                  CAE Inc. (TSX:CAE)       TSX:CAE
# 26                        Cameco Corporation (TSX:CCO)       TSX:CCO
# 27               Canada Goose Holdings Inc. (TSX:GOOS)      TSX:GOOS
# 28               Canada Goose Holdings Inc. (TSX:GOOS)      TSX:GOOS
# 29   Canadian Apartment Properties Real Estate Inve...    TSX:CAR.UN
# ..                                                 ...           ...
# 112                           Shopify Inc. (NYSE:SHOP)     NYSE:SHOP
# 113  SmartCentres Real Estate Investment Trust (TSX...    TSX:SRU.UN
# 114                   SNC-Lavalin Group Inc. (TSX:SNC)       TSX:SNC
# 115                        Spin Master Corp. (TSX:TOY)       TSX:TOY
# 116                             Stantec Inc. (TSX:STN)       TSX:STN
# 117                         Stella-Jones Inc. (TSX:SJ)        TSX:SJ
# 118                  Sun Life Financial Inc. (TSX:SLF)       TSX:SLF
# 119                        Suncor Energy Inc. (TSX:SU)        TSX:SU
# 120                    TC Energy Corporation (TSX:TRP)       TSX:TRP
# 121                Teck Resources Limited (TSX:TECK.B)    TSX:TECK.B
# 122                          TELUS Corporation (TSX:T)         TSX:T
# 123                  TFI International Inc. (TSX:TFII)      TSX:TFII
# 124                  The Bank of Nova Scotia (TSX:BNS)       TSX:BNS
# 125          The Descartes Systems Group Inc (TSX:DSG)       TSX:DSG
# 126                    The Stars Group Inc. (TSX:TSGI)      TSX:TSGI
# 127                    The Stars Group Inc. (TSX:TSGI)      TSX:TSGI
# 128                 The Toronto-Dominion Bank (TSX:TD)        TSX:TD
# 129                 The Toronto-Dominion Bank (TSX:TD)        TSX:TD
# 130              Thomson Reuters Corporation (TSX:TRI)       TSX:TRI
# 131                          TMX Group Limited (TSX:X)         TSX:X
# 132                 Toromont Industries Ltd. (TSX:TIH)       TSX:TIH
# 133                     Tourmaline Oil Corp. (TSX:TOU)       TSX:TOU
# 134                TransAlta Renewables Inc. (TSX:RNW)       TSX:RNW
# 135                    Vermilion Energy Inc. (TSX:VET)       TSX:VET
# 136                 Waste Connections, Inc. (NYSE:WCN)      NYSE:WCN
# 137              West Fraser Timber Co. Ltd. (TSX:WFT)       TSX:WFT
# 138                    WestJet Airlines Ltd. (TSX:WJA)       TSX:WJA
# 139            Wheaton Precious Metals Corp. (TSX:WPM)       TSX:WPM
# 140                          WSP Global Inc. (TSX:WSP)       TSX:WSP
# 141                         Yamana Gold Inc. (TSX:YRI)       TSX:YRI
#
#      TotalAssets  TotalRevenue  GeographicSegments           PrimarySector  \
# 0        10715.5        2990.0                 5.0               Materials
# 1        19197.0       18065.0                 5.0             Industrials
# 2         4455.5         889.4                 4.0               Materials
# 3        12811.6        2247.9                 2.0               Utilities
# 4        30426.3       79562.8                 3.0        Consumer Staples
# 5         6706.3         436.4                 1.0             Real Estate
# 6        23487.7        4256.7                 2.0               Utilities
# 7        23344.0        4888.0                 3.0               Utilities
# 8         1910.7          55.2                 3.0             Health Care
# 9         1910.7          55.2                 3.0             Health Care
# 10        3476.6        1671.6                 9.0               Materials
# 11        3476.6        1671.6                 9.0               Materials
# 12      774048.0       22375.0                 3.0              Financials
# 13       30880.9        9883.4                12.0               Materials
# 14       44336.6       11434.8                17.0             Health Care
# 15       57100.0       23468.0                 1.0  Communication Services
# 16        5173.3        1190.3                 7.0  Information Technology
# 17       34056.2       22154.7                13.0             Industrials
# 18        1233.5        1864.6                 2.0             Industrials
# 19      349705.7       79975.7                 9.0              Financials
# 20       37276.5       50717.2                 8.0             Industrials
# 21       49914.9        6347.8                11.0               Utilities
# 22      167183.4       11170.1                 9.0             Real Estate
# 23       46534.9        4069.1                 6.0               Utilities
# 24        3077.2        5243.8                10.0  Consumer Discretionary
# 25        7165.5        3304.1                15.0             Industrials
# 26        8018.6        2091.7                 6.0                  Energy
# 27         725.4         830.5                 3.0  Consumer Discretionary
# 28         725.4         830.5                 3.0  Consumer Discretionary
# 29       10842.3         688.6                 9.0             Real Estate
# ..           ...           ...                 ...                     ...
# 112       3076.7        1464.5                 5.0  Information Technology
# 113       9459.6         811.1                 1.0             Real Estate
# 114      12939.7       10084.0                11.0             Industrials
# 115       1426.5        2226.3                 8.0  Consumer Discretionary
# 116       4009.9        3355.2                 4.0             Industrials
# 117       2062.2        2123.9                 2.0               Materials
# 118     271827.0       26997.0                 NaN              Financials
# 119      89579.0       38542.0                 3.0                  Energy
# 120      98920.0       13679.0                 3.0                  Energy
# 121      39626.0       12564.0                15.0               Materials
# 122      33065.0       14095.0                 1.0  Communication Services
# 123       4050.0        5123.2                 3.0             Industrials
# 124     998493.0       26164.0                 8.0              Financials
# 125        858.9         361.7                 4.0  Information Technology
# 126      15372.3        2769.0                 8.0  Consumer Discretionary
# 127      15372.3        2769.0                 8.0  Consumer Discretionary
# 128    1334903.0       36354.0                 3.0              Financials
# 129    1334903.0       36354.0                 3.0              Financials
# 130      23261.3        7506.3                 7.0             Industrials
# 131      31657.9        1014.8                 4.0              Financials
# 132       3234.5        3504.2                 3.0             Industrials
# 133      10732.5        1688.0                 1.0                  Energy
# 134       3747.0         446.0                 1.0               Utilities
# 135       6270.7        1526.0                16.0                  Energy
# 136      17230.5        6717.5                 2.0             Industrials
# 137       4791.0        6118.0                 5.0               Materials
# 138       6758.1        4728.4                 4.0             Industrials
# 139       8828.6        1083.5                 9.0               Materials
# 140       7766.6        7908.1                 8.0             Industrials
# 141      10933.9        2454.1                 5.0               Materials
#
#                                                 Name_y  MarketCapitalization  \
# 0                Agnico Eagle Mines Limited (NYSE:AEM)               15892.5
# 1                                  Air Canada (TSX:AC)               11338.6
# 2                           Alamos Gold Inc. (TSX:AGI)                3151.9
# 3          Algonquin Power & Utilities Corp. (TSX:AQN)                8000.0
# 4            Alimentation Couche-Tard Inc. (TSX:ATD.B)               47281.4
# 5    Allied Properties Real Estate Investment Trust...                5621.8
# 6                               AltaGas Ltd. (TSX:ALA)                5512.0
# 7                                ATCO Ltd. (TSX:ACO.X)                5042.8
# 8                       Aurora Cannabis Inc. (TSX:ACB)                8958.5
# 9                       Aurora Cannabis Inc. (TSX:ACB)                8958.5
# 10                              B2Gold Corp. (TSX:BTO)                4105.6
# 11                              B2Gold Corp. (TSX:BTO)                4105.6
# 12                          Bank of Montreal (TSX:BMO)               63889.1
# 13                  Barrick Gold Corporation (TSX:ABX)               37685.1
# 14             Bausch Health Companies Inc. (NYSE:BHC)               10834.5
# 15                                  BCE Inc. (TSX:BCE)               54280.8
# 16                         BlackBerry Limited (TSX:BB)                5139.5
# 17                         Bombardier Inc. (TSX:BBD.B)                5233.7
# 18                 Boyd Group Income Fund (TSX:BYD.UN)                3473.0
# 19        Brookfield Asset Management Inc. (TSX:BAM.A)               61229.8
# 20        Brookfield Business Partners L.P. (NYSE:BBU)                7560.6
# 21   Brookfield Infrastructure Partners L.P. (NYSE:...               16419.9
# 22    Brookfield Property Partners L.P. (NasdaqGS:BPY)               10333.7
# 23     Brookfield Renewable Partners L.P. (TSX:BEP.UN)               14574.3
# 24                                  BRP Inc. (TSX:DOO)                4689.0
# 25                                  CAE Inc. (TSX:CAE)                9683.0
# 26                        Cameco Corporation (TSX:CCO)                5723.2
# 27               Canada Goose Holdings Inc. (TSX:GOOS)                6254.2
# 28               Canada Goose Holdings Inc. (TSX:GOOS)                6254.2
# 29   Canadian Apartment Properties Real Estate Inve...                7813.5
# ..                                                 ...                   ...
# 112                           Shopify Inc. (NYSE:SHOP)               45501.3
# 113  SmartCentres Real Estate Investment Trust (TSX...                4775.5
# 114                   SNC-Lavalin Group Inc. (TSX:SNC)                4392.4
# 115                        Spin Master Corp. (TSX:TOY)                3791.3
# 116                             Stantec Inc. (TSX:STN)                3549.0
# 117                         Stella-Jones Inc. (TSX:SJ)                3240.5
# 118                  Sun Life Financial Inc. (TSX:SLF)               32306.2
# 119                        Suncor Energy Inc. (TSX:SU)               65928.4
# 120                    TC Energy Corporation (TSX:TRP)               61337.2
# 121                Teck Resources Limited (TSX:TECK.B)               15901.5
# 122                          TELUS Corporation (TSX:T)               29346.7
# 123                  TFI International Inc. (TSX:TFII)                3241.5
# 124                  The Bank of Nova Scotia (TSX:BNS)               85329.1
# 125          The Descartes Systems Group Inc (TSX:DSG)                4015.2
# 126                    The Stars Group Inc. (TSX:TSGI)                6113.9
# 127                    The Stars Group Inc. (TSX:TSGI)                6113.9
# 128                 The Toronto-Dominion Bank (TSX:TD)              139949.9
# 129                 The Toronto-Dominion Bank (TSX:TD)              139949.9
# 130              Thomson Reuters Corporation (TSX:TRI)               43979.9
# 131                          TMX Group Limited (TSX:X)                5191.6
# 132                 Toromont Industries Ltd. (TSX:TIH)                5103.1
# 133                     Tourmaline Oil Corp. (TSX:TOU)                4600.4
# 134                TransAlta Renewables Inc. (TSX:RNW)                3727.1
# 135                    Vermilion Energy Inc. (TSX:VET)                4419.2
# 136                 Waste Connections, Inc. (NYSE:WCN)               33303.5
# 137              West Fraser Timber Co. Ltd. (TSX:WFT)                3758.8
# 138                    WestJet Airlines Ltd. (TSX:WJA)                3500.6
# 139            Wheaton Precious Metals Corp. (TSX:WPM)               14000.9
# 140                          WSP Global Inc. (TSX:WSP)                7728.9
# 141                         Yamana Gold Inc. (TSX:YRI)                3268.9
#
#      NumberEmployees
# 0             5990.0
# 1            32600.0
# 2             1700.0
# 3             2277.0
# 4           133000.0
# 5              263.0
# 6             2881.0
# 7             6241.0
# 8              967.0
# 9              967.0
# 10            3168.0
# 11            3168.0
# 12           45454.0
# 13           17500.0
# 14           21100.0
# 15           52790.0
# 16            3945.0
# 17           56920.0
# 18            8568.0
# 19          101700.0
# 20           26900.0
# 21            6000.0
# 22           19000.0
# 23            2325.0
# 24           12500.0
# 25           10000.0
# 26            1897.0
# 27            3932.0
# 28            3932.0
# 29             908.0
# ..               ...
# 112           4000.0
# 113            337.0
# 114          52435.0
# 115           1881.0
# 116          22000.0
# 117           2108.0
# 118          22318.0
# 119          12480.0
# 120           7081.0
# 121          10000.0
# 122          58000.0
# 123          17636.0
# 124          99678.0
# 125           1356.0
# 126           4516.0
# 127           4516.0
# 128          87999.0
# 129          87999.0
# 130          25800.0
# 131           1280.0
# 132           6000.0
# 133            237.0
# 134              NaN
# 135            698.0
# 136          16356.0
# 137           7800.0
# 138          11905.0
# 139             39.0
# 140          49000.0
# 141           5165.0
#
# [142 rows x 9 columns]

# %%
# remove the Name_x column. They appear because both df's have the same names.
SPTSXComposite_and_XCap_Employees = SPTSXComposite_and_XCap_Employees.drop('Name_x', 
                                                                          axis='columns')
SPTSXComposite_and_XCap_Employees
# Out:
#            Ticker  TotalAssets  TotalRevenue  GeographicSegments  \
# 0        NYSE:AEM      10715.5        2990.0                 5.0
# 1          TSX:AC      19197.0       18065.0                 5.0
# 2         TSX:AGI       4455.5         889.4                 4.0
# 3         TSX:AQN      12811.6        2247.9                 2.0
# 4       TSX:ATD.B      30426.3       79562.8                 3.0
# 5       TSX:AP.UN       6706.3         436.4                 1.0
# 6         TSX:ALA      23487.7        4256.7                 2.0
# 7       TSX:ACO.X      23344.0        4888.0                 3.0
# 8         TSX:ACB       1910.7          55.2                 3.0
# 9         TSX:ACB       1910.7          55.2                 3.0
# 10        TSX:BTO       3476.6        1671.6                 9.0
# 11        TSX:BTO       3476.6        1671.6                 9.0
# 12        TSX:BMO     774048.0       22375.0                 3.0
# 13        TSX:ABX      30880.9        9883.4                12.0
# 14       NYSE:BHC      44336.6       11434.8                17.0
# 15        TSX:BCE      57100.0       23468.0                 1.0
# 16         TSX:BB       5173.3        1190.3                 7.0
# 17      TSX:BBD.B      34056.2       22154.7                13.0
# 18     TSX:BYD.UN       1233.5        1864.6                 2.0
# 19      TSX:BAM.A     349705.7       79975.7                 9.0
# 20       NYSE:BBU      37276.5       50717.2                 8.0
# 21       NYSE:BIP      49914.9        6347.8                11.0
# 22   NasdaqGS:BPY     167183.4       11170.1                 9.0
# 23     TSX:BEP.UN      46534.9        4069.1                 6.0
# 24        TSX:DOO       3077.2        5243.8                10.0
# 25        TSX:CAE       7165.5        3304.1                15.0
# 26        TSX:CCO       8018.6        2091.7                 6.0
# 27       TSX:GOOS        725.4         830.5                 3.0
# 28       TSX:GOOS        725.4         830.5                 3.0
# 29     TSX:CAR.UN      10842.3         688.6                 9.0
# ..            ...          ...           ...                 ...
# 112     NYSE:SHOP       3076.7        1464.5                 5.0
# 113    TSX:SRU.UN       9459.6         811.1                 1.0
# 114       TSX:SNC      12939.7       10084.0                11.0
# 115       TSX:TOY       1426.5        2226.3                 8.0
# 116       TSX:STN       4009.9        3355.2                 4.0
# 117        TSX:SJ       2062.2        2123.9                 2.0
# 118       TSX:SLF     271827.0       26997.0                 NaN
# 119        TSX:SU      89579.0       38542.0                 3.0
# 120       TSX:TRP      98920.0       13679.0                 3.0
# 121    TSX:TECK.B      39626.0       12564.0                15.0
# 122         TSX:T      33065.0       14095.0                 1.0
# 123      TSX:TFII       4050.0        5123.2                 3.0
# 124       TSX:BNS     998493.0       26164.0                 8.0
# 125       TSX:DSG        858.9         361.7                 4.0
# 126      TSX:TSGI      15372.3        2769.0                 8.0
# 127      TSX:TSGI      15372.3        2769.0                 8.0
# 128        TSX:TD    1334903.0       36354.0                 3.0
# 129        TSX:TD    1334903.0       36354.0                 3.0
# 130       TSX:TRI      23261.3        7506.3                 7.0
# 131         TSX:X      31657.9        1014.8                 4.0
# 132       TSX:TIH       3234.5        3504.2                 3.0
# 133       TSX:TOU      10732.5        1688.0                 1.0
# 134       TSX:RNW       3747.0         446.0                 1.0
# 135       TSX:VET       6270.7        1526.0                16.0
# 136      NYSE:WCN      17230.5        6717.5                 2.0
# 137       TSX:WFT       4791.0        6118.0                 5.0
# 138       TSX:WJA       6758.1        4728.4                 4.0
# 139       TSX:WPM       8828.6        1083.5                 9.0
# 140       TSX:WSP       7766.6        7908.1                 8.0
# 141       TSX:YRI      10933.9        2454.1                 5.0
#
#               PrimarySector  \
# 0                 Materials
# 1               Industrials
# 2                 Materials
# 3                 Utilities
# 4          Consumer Staples
# 5               Real Estate
# 6                 Utilities
# 7                 Utilities
# 8               Health Care
# 9               Health Care
# 10                Materials
# 11                Materials
# 12               Financials
# 13                Materials
# 14              Health Care
# 15   Communication Services
# 16   Information Technology
# 17              Industrials
# 18              Industrials
# 19               Financials
# 20              Industrials
# 21                Utilities
# 22              Real Estate
# 23                Utilities
# 24   Consumer Discretionary
# 25              Industrials
# 26                   Energy
# 27   Consumer Discretionary
# 28   Consumer Discretionary
# 29              Real Estate
# ..                      ...
# 112  Information Technology
# 113             Real Estate
# 114             Industrials
# 115  Consumer Discretionary
# 116             Industrials
# 117               Materials
# 118              Financials
# 119                  Energy
# 120                  Energy
# 121               Materials
# 122  Communication Services
# 123             Industrials
# 124              Financials
# 125  Information Technology
# 126  Consumer Discretionary
# 127  Consumer Discretionary
# 128              Financials
# 129              Financials
# 130             Industrials
# 131              Financials
# 132             Industrials
# 133                  Energy
# 134               Utilities
# 135                  Energy
# 136             Industrials
# 137               Materials
# 138             Industrials
# 139               Materials
# 140             Industrials
# 141               Materials
#
#                                                 Name_y  MarketCapitalization  \
# 0                Agnico Eagle Mines Limited (NYSE:AEM)               15892.5
# 1                                  Air Canada (TSX:AC)               11338.6
# 2                           Alamos Gold Inc. (TSX:AGI)                3151.9
# 3          Algonquin Power & Utilities Corp. (TSX:AQN)                8000.0
# 4            Alimentation Couche-Tard Inc. (TSX:ATD.B)               47281.4
# 5    Allied Properties Real Estate Investment Trust...                5621.8
# 6                               AltaGas Ltd. (TSX:ALA)                5512.0
# 7                                ATCO Ltd. (TSX:ACO.X)                5042.8
# 8                       Aurora Cannabis Inc. (TSX:ACB)                8958.5
# 9                       Aurora Cannabis Inc. (TSX:ACB)                8958.5
# 10                              B2Gold Corp. (TSX:BTO)                4105.6
# 11                              B2Gold Corp. (TSX:BTO)                4105.6
# 12                          Bank of Montreal (TSX:BMO)               63889.1
# 13                  Barrick Gold Corporation (TSX:ABX)               37685.1
# 14             Bausch Health Companies Inc. (NYSE:BHC)               10834.5
# 15                                  BCE Inc. (TSX:BCE)               54280.8
# 16                         BlackBerry Limited (TSX:BB)                5139.5
# 17                         Bombardier Inc. (TSX:BBD.B)                5233.7
# 18                 Boyd Group Income Fund (TSX:BYD.UN)                3473.0
# 19        Brookfield Asset Management Inc. (TSX:BAM.A)               61229.8
# 20        Brookfield Business Partners L.P. (NYSE:BBU)                7560.6
# 21   Brookfield Infrastructure Partners L.P. (NYSE:...               16419.9
# 22    Brookfield Property Partners L.P. (NasdaqGS:BPY)               10333.7
# 23     Brookfield Renewable Partners L.P. (TSX:BEP.UN)               14574.3
# 24                                  BRP Inc. (TSX:DOO)                4689.0
# 25                                  CAE Inc. (TSX:CAE)                9683.0
# 26                        Cameco Corporation (TSX:CCO)                5723.2
# 27               Canada Goose Holdings Inc. (TSX:GOOS)                6254.2
# 28               Canada Goose Holdings Inc. (TSX:GOOS)                6254.2
# 29   Canadian Apartment Properties Real Estate Inve...                7813.5
# ..                                                 ...                   ...
# 112                           Shopify Inc. (NYSE:SHOP)               45501.3
# 113  SmartCentres Real Estate Investment Trust (TSX...                4775.5
# 114                   SNC-Lavalin Group Inc. (TSX:SNC)                4392.4
# 115                        Spin Master Corp. (TSX:TOY)                3791.3
# 116                             Stantec Inc. (TSX:STN)                3549.0
# 117                         Stella-Jones Inc. (TSX:SJ)                3240.5
# 118                  Sun Life Financial Inc. (TSX:SLF)               32306.2
# 119                        Suncor Energy Inc. (TSX:SU)               65928.4
# 120                    TC Energy Corporation (TSX:TRP)               61337.2
# 121                Teck Resources Limited (TSX:TECK.B)               15901.5
# 122                          TELUS Corporation (TSX:T)               29346.7
# 123                  TFI International Inc. (TSX:TFII)                3241.5
# 124                  The Bank of Nova Scotia (TSX:BNS)               85329.1
# 125          The Descartes Systems Group Inc (TSX:DSG)                4015.2
# 126                    The Stars Group Inc. (TSX:TSGI)                6113.9
# 127                    The Stars Group Inc. (TSX:TSGI)                6113.9
# 128                 The Toronto-Dominion Bank (TSX:TD)              139949.9
# 129                 The Toronto-Dominion Bank (TSX:TD)              139949.9
# 130              Thomson Reuters Corporation (TSX:TRI)               43979.9
# 131                          TMX Group Limited (TSX:X)                5191.6
# 132                 Toromont Industries Ltd. (TSX:TIH)                5103.1
# 133                     Tourmaline Oil Corp. (TSX:TOU)                4600.4
# 134                TransAlta Renewables Inc. (TSX:RNW)                3727.1
# 135                    Vermilion Energy Inc. (TSX:VET)                4419.2
# 136                 Waste Connections, Inc. (NYSE:WCN)               33303.5
# 137              West Fraser Timber Co. Ltd. (TSX:WFT)                3758.8
# 138                    WestJet Airlines Ltd. (TSX:WJA)                3500.6
# 139            Wheaton Precious Metals Corp. (TSX:WPM)               14000.9
# 140                          WSP Global Inc. (TSX:WSP)                7728.9
# 141                         Yamana Gold Inc. (TSX:YRI)                3268.9
#
#      NumberEmployees
# 0             5990.0
# 1            32600.0
# 2             1700.0
# 3             2277.0
# 4           133000.0
# 5              263.0
# 6             2881.0
# 7             6241.0
# 8              967.0
# 9              967.0
# 10            3168.0
# 11            3168.0
# 12           45454.0
# 13           17500.0
# 14           21100.0
# 15           52790.0
# 16            3945.0
# 17           56920.0
# 18            8568.0
# 19          101700.0
# 20           26900.0
# 21            6000.0
# 22           19000.0
# 23            2325.0
# 24           12500.0
# 25           10000.0
# 26            1897.0
# 27            3932.0
# 28            3932.0
# 29             908.0
# ..               ...
# 112           4000.0
# 113            337.0
# 114          52435.0
# 115           1881.0
# 116          22000.0
# 117           2108.0
# 118          22318.0
# 119          12480.0
# 120           7081.0
# 121          10000.0
# 122          58000.0
# 123          17636.0
# 124          99678.0
# 125           1356.0
# 126           4516.0
# 127           4516.0
# 128          87999.0
# 129          87999.0
# 130          25800.0
# 131           1280.0
# 132           6000.0
# 133            237.0
# 134              NaN
# 135            698.0
# 136          16356.0
# 137           7800.0
# 138          11905.0
# 139             39.0
# 140          49000.0
# 141           5165.0
#
# [142 rows x 8 columns]

# %%
# remove the Name_y column. They appear because both df's have the same names.
SPTSXComposite_and_XCap_Employees = SPTSXComposite_and_XCap_Employees.drop('Name_y', 
                                                                          axis='columns')
SPTSXComposite_and_XCap_Employees
# Out:
#            Ticker  TotalAssets  TotalRevenue  GeographicSegments  \
# 0        NYSE:AEM      10715.5        2990.0                 5.0
# 1          TSX:AC      19197.0       18065.0                 5.0
# 2         TSX:AGI       4455.5         889.4                 4.0
# 3         TSX:AQN      12811.6        2247.9                 2.0
# 4       TSX:ATD.B      30426.3       79562.8                 3.0
# 5       TSX:AP.UN       6706.3         436.4                 1.0
# 6         TSX:ALA      23487.7        4256.7                 2.0
# 7       TSX:ACO.X      23344.0        4888.0                 3.0
# 8         TSX:ACB       1910.7          55.2                 3.0
# 9         TSX:ACB       1910.7          55.2                 3.0
# 10        TSX:BTO       3476.6        1671.6                 9.0
# 11        TSX:BTO       3476.6        1671.6                 9.0
# 12        TSX:BMO     774048.0       22375.0                 3.0
# 13        TSX:ABX      30880.9        9883.4                12.0
# 14       NYSE:BHC      44336.6       11434.8                17.0
# 15        TSX:BCE      57100.0       23468.0                 1.0
# 16         TSX:BB       5173.3        1190.3                 7.0
# 17      TSX:BBD.B      34056.2       22154.7                13.0
# 18     TSX:BYD.UN       1233.5        1864.6                 2.0
# 19      TSX:BAM.A     349705.7       79975.7                 9.0
# 20       NYSE:BBU      37276.5       50717.2                 8.0
# 21       NYSE:BIP      49914.9        6347.8                11.0
# 22   NasdaqGS:BPY     167183.4       11170.1                 9.0
# 23     TSX:BEP.UN      46534.9        4069.1                 6.0
# 24        TSX:DOO       3077.2        5243.8                10.0
# 25        TSX:CAE       7165.5        3304.1                15.0
# 26        TSX:CCO       8018.6        2091.7                 6.0
# 27       TSX:GOOS        725.4         830.5                 3.0
# 28       TSX:GOOS        725.4         830.5                 3.0
# 29     TSX:CAR.UN      10842.3         688.6                 9.0
# ..            ...          ...           ...                 ...
# 112     NYSE:SHOP       3076.7        1464.5                 5.0
# 113    TSX:SRU.UN       9459.6         811.1                 1.0
# 114       TSX:SNC      12939.7       10084.0                11.0
# 115       TSX:TOY       1426.5        2226.3                 8.0
# 116       TSX:STN       4009.9        3355.2                 4.0
# 117        TSX:SJ       2062.2        2123.9                 2.0
# 118       TSX:SLF     271827.0       26997.0                 NaN
# 119        TSX:SU      89579.0       38542.0                 3.0
# 120       TSX:TRP      98920.0       13679.0                 3.0
# 121    TSX:TECK.B      39626.0       12564.0                15.0
# 122         TSX:T      33065.0       14095.0                 1.0
# 123      TSX:TFII       4050.0        5123.2                 3.0
# 124       TSX:BNS     998493.0       26164.0                 8.0
# 125       TSX:DSG        858.9         361.7                 4.0
# 126      TSX:TSGI      15372.3        2769.0                 8.0
# 127      TSX:TSGI      15372.3        2769.0                 8.0
# 128        TSX:TD    1334903.0       36354.0                 3.0
# 129        TSX:TD    1334903.0       36354.0                 3.0
# 130       TSX:TRI      23261.3        7506.3                 7.0
# 131         TSX:X      31657.9        1014.8                 4.0
# 132       TSX:TIH       3234.5        3504.2                 3.0
# 133       TSX:TOU      10732.5        1688.0                 1.0
# 134       TSX:RNW       3747.0         446.0                 1.0
# 135       TSX:VET       6270.7        1526.0                16.0
# 136      NYSE:WCN      17230.5        6717.5                 2.0
# 137       TSX:WFT       4791.0        6118.0                 5.0
# 138       TSX:WJA       6758.1        4728.4                 4.0
# 139       TSX:WPM       8828.6        1083.5                 9.0
# 140       TSX:WSP       7766.6        7908.1                 8.0
# 141       TSX:YRI      10933.9        2454.1                 5.0
#
#               PrimarySector  MarketCapitalization  NumberEmployees
# 0                 Materials               15892.5           5990.0
# 1               Industrials               11338.6          32600.0
# 2                 Materials                3151.9           1700.0
# 3                 Utilities                8000.0           2277.0
# 4          Consumer Staples               47281.4         133000.0
# 5               Real Estate                5621.8            263.0
# 6                 Utilities                5512.0           2881.0
# 7                 Utilities                5042.8           6241.0
# 8               Health Care                8958.5            967.0
# 9               Health Care                8958.5            967.0
# 10                Materials                4105.6           3168.0
# 11                Materials                4105.6           3168.0
# 12               Financials               63889.1          45454.0
# 13                Materials               37685.1          17500.0
# 14              Health Care               10834.5          21100.0
# 15   Communication Services               54280.8          52790.0
# 16   Information Technology                5139.5           3945.0
# 17              Industrials                5233.7          56920.0
# 18              Industrials                3473.0           8568.0
# 19               Financials               61229.8         101700.0
# 20              Industrials                7560.6          26900.0
# 21                Utilities               16419.9           6000.0
# 22              Real Estate               10333.7          19000.0
# 23                Utilities               14574.3           2325.0
# 24   Consumer Discretionary                4689.0          12500.0
# 25              Industrials                9683.0          10000.0
# 26                   Energy                5723.2           1897.0
# 27   Consumer Discretionary                6254.2           3932.0
# 28   Consumer Discretionary                6254.2           3932.0
# 29              Real Estate                7813.5            908.0
# ..                      ...                   ...              ...
# 112  Information Technology               45501.3           4000.0
# 113             Real Estate                4775.5            337.0
# 114             Industrials                4392.4          52435.0
# 115  Consumer Discretionary                3791.3           1881.0
# 116             Industrials                3549.0          22000.0
# 117               Materials                3240.5           2108.0
# 118              Financials               32306.2          22318.0
# 119                  Energy               65928.4          12480.0
# 120                  Energy               61337.2           7081.0
# 121               Materials               15901.5          10000.0
# 122  Communication Services               29346.7          58000.0
# 123             Industrials                3241.5          17636.0
# 124              Financials               85329.1          99678.0
# 125  Information Technology                4015.2           1356.0
# 126  Consumer Discretionary                6113.9           4516.0
# 127  Consumer Discretionary                6113.9           4516.0
# 128              Financials              139949.9          87999.0
# 129              Financials              139949.9          87999.0
# 130             Industrials               43979.9          25800.0
# 131              Financials                5191.6           1280.0
# 132             Industrials                5103.1           6000.0
# 133                  Energy                4600.4            237.0
# 134               Utilities                3727.1              NaN
# 135                  Energy                4419.2            698.0
# 136             Industrials               33303.5          16356.0
# 137               Materials                3758.8           7800.0
# 138             Industrials                3500.6          11905.0
# 139               Materials               14000.9             39.0
# 140             Industrials                7728.9          49000.0
# 141               Materials                3268.9           5165.0
#
# [142 rows x 7 columns]

# %%
# SPTSXComposite_and_XCap_Employees still has duplicates.
SPTSXComposite_and_XCap_Employees.loc[SPTSXComposite_and_XCap_Employees.duplicated()]
# Out:
#             Ticker  TotalAssets  TotalRevenue  GeographicSegments  \
# 9          TSX:ACB       1910.7          55.2                 3.0
# 11         TSX:BTO       3476.6        1671.6                 9.0
# 28        TSX:GOOS        725.4         830.5                 3.0
# 52         TSX:EMA      32314.0        6524.0                 5.0
# 54       TSX:EMP.A       9602.4       25249.3                 NaN
# 93   NasdaqGS:OTEX      10378.2        3752.5                 6.0
# 95        TSX:PAAS       2643.8        1070.5                 NaN
# 97         TSX:PXT       2356.5        1136.6                 2.0
# 127       TSX:TSGI      15372.3        2769.0                 8.0
# 129         TSX:TD    1334903.0       36354.0                 3.0
#
#               PrimarySector  MarketCapitalization  NumberEmployees
# 9               Health Care                8958.5            967.0
# 11                Materials                4105.6           3168.0
# 28   Consumer Discretionary                6254.2           3932.0
# 52                Utilities               12873.1           7523.0
# 54         Consumer Staples                9112.5         123000.0
# 93   Information Technology               14905.9          13100.0
# 95                Materials                3565.0           4530.0
# 97                   Energy                3129.7            279.0
# 127  Consumer Discretionary                6113.9           4516.0
# 129              Financials              139949.9          87999.0

# %%
# from SPTSXComposite_and_XCap_Employees, drop the duplicates anyway
SPTSXComposite_and_XCap_Employees = SPTSXComposite_and_XCap_Employees.drop_duplicates(keep='first')
print(SPTSXComposite_and_XCap_Employees.shape)
# Out:
# (132, 7)

# %%
SPTSXComposite_and_XCap_Employees = SPTSXComposite_and_XCap_Employees.drop('TotalRevenue', axis='columns')
SPTSXComposite_and_XCap_Employees = SPTSXComposite_and_XCap_Employees.drop('GeographicSegments', axis='columns')

# %%
# what we have so far:
SPTSXComposite_and_XCap_Employees
# Out:
#            Ticker  TotalAssets           PrimarySector  MarketCapitalization  \
# 0        NYSE:AEM      10715.5               Materials               15892.5
# 1          TSX:AC      19197.0             Industrials               11338.6
# 2         TSX:AGI       4455.5               Materials                3151.9
# 3         TSX:AQN      12811.6               Utilities                8000.0
# 4       TSX:ATD.B      30426.3        Consumer Staples               47281.4
# 5       TSX:AP.UN       6706.3             Real Estate                5621.8
# 6         TSX:ALA      23487.7               Utilities                5512.0
# 7       TSX:ACO.X      23344.0               Utilities                5042.8
# 8         TSX:ACB       1910.7             Health Care                8958.5
# 10        TSX:BTO       3476.6               Materials                4105.6
# 12        TSX:BMO     774048.0              Financials               63889.1
# 13        TSX:ABX      30880.9               Materials               37685.1
# 14       NYSE:BHC      44336.6             Health Care               10834.5
# 15        TSX:BCE      57100.0  Communication Services               54280.8
# 16         TSX:BB       5173.3  Information Technology                5139.5
# 17      TSX:BBD.B      34056.2             Industrials                5233.7
# 18     TSX:BYD.UN       1233.5             Industrials                3473.0
# 19      TSX:BAM.A     349705.7              Financials               61229.8
# 20       NYSE:BBU      37276.5             Industrials                7560.6
# 21       NYSE:BIP      49914.9               Utilities               16419.9
# 22   NasdaqGS:BPY     167183.4             Real Estate               10333.7
# 23     TSX:BEP.UN      46534.9               Utilities               14574.3
# 24        TSX:DOO       3077.2  Consumer Discretionary                4689.0
# 25        TSX:CAE       7165.5             Industrials                9683.0
# 26        TSX:CCO       8018.6                  Energy                5723.2
# 27       TSX:GOOS        725.4  Consumer Discretionary                6254.2
# 29     TSX:CAR.UN      10842.3             Real Estate                7813.5
# 30         TSX:CM     597099.0              Financials               45870.7
# 31        TSX:CNR      41214.0             Industrials               88154.5
# 32        TSX:CNQ      71559.0                  Energy               43045.8
# ..            ...          ...                     ...                   ...
# 110       TSX:SAP       9885.6        Consumer Staples               15380.8
# 111     TSX:SJR.B      14424.0  Communication Services               13588.2
# 112     NYSE:SHOP       3076.7  Information Technology               45501.3
# 113    TSX:SRU.UN       9459.6             Real Estate                4775.5
# 114       TSX:SNC      12939.7             Industrials                4392.4
# 115       TSX:TOY       1426.5  Consumer Discretionary                3791.3
# 116       TSX:STN       4009.9             Industrials                3549.0
# 117        TSX:SJ       2062.2               Materials                3240.5
# 118       TSX:SLF     271827.0              Financials               32306.2
# 119        TSX:SU      89579.0                  Energy               65928.4
# 120       TSX:TRP      98920.0                  Energy               61337.2
# 121    TSX:TECK.B      39626.0               Materials               15901.5
# 122         TSX:T      33065.0  Communication Services               29346.7
# 123      TSX:TFII       4050.0             Industrials                3241.5
# 124       TSX:BNS     998493.0              Financials               85329.1
# 125       TSX:DSG        858.9  Information Technology                4015.2
# 126      TSX:TSGI      15372.3  Consumer Discretionary                6113.9
# 128        TSX:TD    1334903.0              Financials              139949.9
# 130       TSX:TRI      23261.3             Industrials               43979.9
# 131         TSX:X      31657.9              Financials                5191.6
# 132       TSX:TIH       3234.5             Industrials                5103.1
# 133       TSX:TOU      10732.5                  Energy                4600.4
# 134       TSX:RNW       3747.0               Utilities                3727.1
# 135       TSX:VET       6270.7                  Energy                4419.2
# 136      NYSE:WCN      17230.5             Industrials               33303.5
# 137       TSX:WFT       4791.0               Materials                3758.8
# 138       TSX:WJA       6758.1             Industrials                3500.6
# 139       TSX:WPM       8828.6               Materials               14000.9
# 140       TSX:WSP       7766.6             Industrials                7728.9
# 141       TSX:YRI      10933.9               Materials                3268.9
#
#      NumberEmployees
# 0             5990.0
# 1            32600.0
# 2             1700.0
# 3             2277.0
# 4           133000.0
# 5              263.0
# 6             2881.0
# 7             6241.0
# 8              967.0
# 10            3168.0
# 12           45454.0
# 13           17500.0
# 14           21100.0
# 15           52790.0
# 16            3945.0
# 17           56920.0
# 18            8568.0
# 19          101700.0
# 20           26900.0
# 21            6000.0
# 22           19000.0
# 23            2325.0
# 24           12500.0
# 25           10000.0
# 26            1897.0
# 27            3932.0
# 29             908.0
# 30           44797.0
# 31           27215.0
# 32            9973.0
# ..               ...
# 110          16800.0
# 111          10000.0
# 112           4000.0
# 113            337.0
# 114          52435.0
# 115           1881.0
# 116          22000.0
# 117           2108.0
# 118          22318.0
# 119          12480.0
# 120           7081.0
# 121          10000.0
# 122          58000.0
# 123          17636.0
# 124          99678.0
# 125           1356.0
# 126           4516.0
# 128          87999.0
# 130          25800.0
# 131           1280.0
# 132           6000.0
# 133            237.0
# 134              NaN
# 135            698.0
# 136          16356.0
# 137           7800.0
# 138          11905.0
# 139             39.0
# 140          49000.0
# 141           5165.0
#
# [132 rows x 5 columns]

# %%
'''
Dataframes:
Variables contained in select Dataframes:
SPTSXComposite_and_XCap_Employees - contains Ticker, Total Assets, Number of Employees,
Market Capitalization

Series:
TotalNoTransactions - Total Number of Transactions 
AvgTransactionValue - Average Transaction Value

We need to combine the two series into a Dataframe somehow, before the left merge.
We now have 2 Dataframes and 2 Series containing the columns we want.
'''
'''
Reiteration of question:
- 1. Create a DataFrame containing the following variables: Ticker, Total Assets, 
Number of Employees, Market Capitalization, Total Number of Transactions, Average 
Transaction Value (you will have to merge multiple datasets). 
Make sure you check the shape of your final dataset! (Hint: Duplicates)
'''
# Out:
# '\nReiteration of question:\n- 1. Create a DataFrame containing the following variables: Ticker, Total Assets, \nNumber of Employees, Market Capitalization, Total Number of Transactions, Average \nTransaction Value (you will have to merge multiple datasets). \nMake sure you check the shape of your final dataset! (Hint: Duplicates)\n'

# %%
# convert TotalNoTransactions to dataframe
TotalNoTransactions_Frame = TotalNoTransactions.to_frame()
TotalNoTransactions_Frame
# Out:
#                TransactionType
# Ticker
# AMEX:GTE                     4
# NYSE:AEM                     4
# NYSE:BHC                     9
# NYSE:MUX                     5
# NYSE:RBA                     2
# NYSE:SHOP                    4
# NYSE:WCN                    12
# NasdaqGS:OTEX                3
# OTCPK:FFXD.F                 2
# OTCPK:FFXX.F                 3
# TSX:AAV                      1
# TSX:AC                       1
# TSX:ACB                     14
# TSX:ACI                      3
# TSX:ACO.X                    1
# TSX:ADVZ                     3
# TSX:ADW.A                    1
# TSX:AFN                      5
# TSX:AGI                      2
# TSX:AI                       6
# TSX:AII                      8
# TSX:AKG                      1
# TSX:AKU                      2
# TSX:ALA                      7
# TSX:ALEF                     2
# TSX:ALS                      2
# TSX:ALYA                     1
# TSX:AOI                      1
# TSX:AP.UN                    7
# TSX:APHA                     7
# ...                        ...
# TSX:TSGI                     3
# TSX:TSU                      2
# TSX:TV                       2
# TSX:TVE                      2
# TSX:TVK                      2
# TSX:TWM                      4
# TSX:TXG                      1
# TSX:U                        3
# TSX:UNS                      1
# TSX:VB                       1
# TSX:VET                      1
# TSX:VFF                      4
# TSX:VII                      3
# TSX:VLE                      2
# TSX:WCP                      6
# TSX:WDO                      1
# TSX:WEED                     9
# TSX:WFT                      1
# TSX:WIR.U                    6
# TSX:WJA                      2
# TSX:WPM                      1
# TSX:WPRT                     2
# TSX:WTE                      1
# TSX:X                        2
# TSX:XAU                      2
# TSX:XTC                      1
# TSX:YGR                      1
# TSX:YRI                      1
# TSX:ZCL                      1
# TSX:ZYME                     4
#
# [366 rows x 1 columns]

# %%
# convert AvgTransactionValue to dataframe
AvgTransactionValue_Frame = AvgTransactionValue.to_frame()
AvgTransactionValue_Frame
# Out:
#                TransactionValue
# Ticker
# AMEX:GTE             206.620000
# NYSE:AEM             401.837500
# NYSE:BHC            1452.904444
# NYSE:MUX              35.492000
# NYSE:RBA             331.110000
# NYSE:SHOP            604.657500
# NYSE:WCN             198.457500
# NasdaqGS:OTEX        622.963333
# OTCPK:FFXD.F         329.755000
# OTCPK:FFXX.F         253.196667
# TSX:AAV               87.540000
# TSX:AC               200.000000
# TSX:ACB              106.191429
# TSX:ACI              263.006667
# TSX:ACO.X            200.000000
# TSX:ADVZ             474.386667
# TSX:ADW.A              2.250000
# TSX:AFN               77.172000
# TSX:AGI              170.055000
# TSX:AI                29.176667
# TSX:AII                2.445000
# TSX:AKG               17.660000
# TSX:AKU               23.660000
# TSX:ALA              571.747143
# TSX:ALEF              20.105000
# TSX:ALS               67.505000
# TSX:ALYA              52.810000
# TSX:AOI               22.730000
# TSX:AP.UN            202.182857
# TSX:APHA             137.321429
# ...                         ...
# TSX:TSGI             972.600000
# TSX:TSU               65.770000
# TSX:TV               138.775000
# TSX:TVE               55.005000
# TSX:TVK               10.220000
# TSX:TWM               79.592500
# TSX:TXG               55.060000
# TSX:U                 19.343333
# TSX:UNS               36.340000
# TSX:VB                 5.000000
# TSX:VET              402.200000
# TSX:VFF               15.885000
# TSX:VII              604.486667
# TSX:VLE               35.485000
# TSX:WCP              231.671667
# TSX:WDO               15.020000
# TSX:WEED             686.024444
# TSX:WFT              525.180000
# TSX:WIR.U             90.301667
# TSX:WJA              299.185000
# TSX:WPM              713.300000
# TSX:WPRT              33.275000
# TSX:WTE               84.060000
# TSX:X                250.000000
# TSX:XAU               33.320000
# TSX:XTC               10.020000
# TSX:YGR               10.000000
# TSX:YRI              385.610000
# TSX:ZCL              322.160000
# TSX:ZYME              77.510000
#
# [366 rows x 1 columns]

# %%
# merge TotalNoTransactions_Frame with AvgTransactionValue_Frame called Transactions_Frame:
'''
df1_df2_combined = df1.merge(df2, on='Ticker', how='left')
print(df1_df2_combined.shape)
print()
df1_df2_combined
'''
Transactions_Frame = TotalNoTransactions_Frame.merge(AvgTransactionValue_Frame, 
                                                     on='Ticker', how='left')
print(Transactions_Frame.shape)
print()
Transactions_Frame
# Out:
# (366, 2)
#                TransactionType  TransactionValue
# Ticker
# AMEX:GTE                     4        206.620000
# NYSE:AEM                     4        401.837500
# NYSE:BHC                     9       1452.904444
# NYSE:MUX                     5         35.492000
# NYSE:RBA                     2        331.110000
# NYSE:SHOP                    4        604.657500
# NYSE:WCN                    12        198.457500
# NasdaqGS:OTEX                3        622.963333
# OTCPK:FFXD.F                 2        329.755000
# OTCPK:FFXX.F                 3        253.196667
# TSX:AAV                      1         87.540000
# TSX:AC                       1        200.000000
# TSX:ACB                     14        106.191429
# TSX:ACI                      3        263.006667
# TSX:ACO.X                    1        200.000000
# TSX:ADVZ                     3        474.386667
# TSX:ADW.A                    1          2.250000
# TSX:AFN                      5         77.172000
# TSX:AGI                      2        170.055000
# TSX:AI                       6         29.176667
# TSX:AII                      8          2.445000
# TSX:AKG                      1         17.660000
# TSX:AKU                      2         23.660000
# TSX:ALA                      7        571.747143
# TSX:ALEF                     2         20.105000
# TSX:ALS                      2         67.505000
# TSX:ALYA                     1         52.810000
# TSX:AOI                      1         22.730000
# TSX:AP.UN                    7        202.182857
# TSX:APHA                     7        137.321429
# ...                        ...               ...
# TSX:TSGI                     3        972.600000
# TSX:TSU                      2         65.770000
# TSX:TV                       2        138.775000
# TSX:TVE                      2         55.005000
# TSX:TVK                      2         10.220000
# TSX:TWM                      4         79.592500
# TSX:TXG                      1         55.060000
# TSX:U                        3         19.343333
# TSX:UNS                      1         36.340000
# TSX:VB                       1          5.000000
# TSX:VET                      1        402.200000
# TSX:VFF                      4         15.885000
# TSX:VII                      3        604.486667
# TSX:VLE                      2         35.485000
# TSX:WCP                      6        231.671667
# TSX:WDO                      1         15.020000
# TSX:WEED                     9        686.024444
# TSX:WFT                      1        525.180000
# TSX:WIR.U                    6         90.301667
# TSX:WJA                      2        299.185000
# TSX:WPM                      1        713.300000
# TSX:WPRT                     2         33.275000
# TSX:WTE                      1         84.060000
# TSX:X                        2        250.000000
# TSX:XAU                      2         33.320000
# TSX:XTC                      1         10.020000
# TSX:YGR                      1         10.000000
# TSX:YRI                      1        385.610000
# TSX:ZCL                      1        322.160000
# TSX:ZYME                     4         77.510000
#
# [366 rows x 2 columns]

# %%
'''
Dataframes:
Variables contained in select Dataframes:
- SPTSXComposite_and_XCap_Employees - contains Ticker, Total Assets, Number of Employees,
Market Capitalization
- Transactions_Frame - contains Total Number of Transactions, Average Transaction Value
Now that we have the two dataframes with the required columns, merge them.
Note that Transactions_Frame has more rows, but we want it to be left merged with
SPTSXComposite_and_XCap_Employees because we want a resultant dataframe that does not
have non-TSX rows,
'''
'''
Reiteration of question:
- 1. Create a DataFrame containing the following variables: Ticker, Total Assets, 
Number of Employees, Market Capitalization, Total Number of Transactions, Average 
Transaction Value (you will have to merge multiple datasets). 
Make sure you check the shape of your final dataset! (Hint: Duplicates)
'''

'''
df1_df2_combined = df1.merge(df2, on='Ticker', how='left')
print(df1_df2_combined.shape)
print()
df1_df2_combined
'''
# create a resultant dataframe, called SPTSX_Frame
SPTSX_Frame = SPTSXComposite_and_XCap_Employees.merge(Transactions_Frame, 
                                                      on='Ticker', how='left')
print(SPTSX_Frame.shape)
print()
SPTSX_Frame
# Out:
# (132, 7)
#            Ticker  TotalAssets           PrimarySector  MarketCapitalization  \
# 0        NYSE:AEM      10715.5               Materials               15892.5
# 1          TSX:AC      19197.0             Industrials               11338.6
# 2         TSX:AGI       4455.5               Materials                3151.9
# 3         TSX:AQN      12811.6               Utilities                8000.0
# 4       TSX:ATD.B      30426.3        Consumer Staples               47281.4
# 5       TSX:AP.UN       6706.3             Real Estate                5621.8
# 6         TSX:ALA      23487.7               Utilities                5512.0
# 7       TSX:ACO.X      23344.0               Utilities                5042.8
# 8         TSX:ACB       1910.7             Health Care                8958.5
# 9         TSX:BTO       3476.6               Materials                4105.6
# 10        TSX:BMO     774048.0              Financials               63889.1
# 11        TSX:ABX      30880.9               Materials               37685.1
# 12       NYSE:BHC      44336.6             Health Care               10834.5
# 13        TSX:BCE      57100.0  Communication Services               54280.8
# 14         TSX:BB       5173.3  Information Technology                5139.5
# 15      TSX:BBD.B      34056.2             Industrials                5233.7
# 16     TSX:BYD.UN       1233.5             Industrials                3473.0
# 17      TSX:BAM.A     349705.7              Financials               61229.8
# 18       NYSE:BBU      37276.5             Industrials                7560.6
# 19       NYSE:BIP      49914.9               Utilities               16419.9
# 20   NasdaqGS:BPY     167183.4             Real Estate               10333.7
# 21     TSX:BEP.UN      46534.9               Utilities               14574.3
# 22        TSX:DOO       3077.2  Consumer Discretionary                4689.0
# 23        TSX:CAE       7165.5             Industrials                9683.0
# 24        TSX:CCO       8018.6                  Energy                5723.2
# 25       TSX:GOOS        725.4  Consumer Discretionary                6254.2
# 26     TSX:CAR.UN      10842.3             Real Estate                7813.5
# 27         TSX:CM     597099.0              Financials               45870.7
# 28        TSX:CNR      41214.0             Industrials               88154.5
# 29        TSX:CNQ      71559.0                  Energy               43045.8
# ..            ...          ...                     ...                   ...
# 102       TSX:SAP       9885.6        Consumer Staples               15380.8
# 103     TSX:SJR.B      14424.0  Communication Services               13588.2
# 104     NYSE:SHOP       3076.7  Information Technology               45501.3
# 105    TSX:SRU.UN       9459.6             Real Estate                4775.5
# 106       TSX:SNC      12939.7             Industrials                4392.4
# 107       TSX:TOY       1426.5  Consumer Discretionary                3791.3
# 108       TSX:STN       4009.9             Industrials                3549.0
# 109        TSX:SJ       2062.2               Materials                3240.5
# 110       TSX:SLF     271827.0              Financials               32306.2
# 111        TSX:SU      89579.0                  Energy               65928.4
# 112       TSX:TRP      98920.0                  Energy               61337.2
# 113    TSX:TECK.B      39626.0               Materials               15901.5
# 114         TSX:T      33065.0  Communication Services               29346.7
# 115      TSX:TFII       4050.0             Industrials                3241.5
# 116       TSX:BNS     998493.0              Financials               85329.1
# 117       TSX:DSG        858.9  Information Technology                4015.2
# 118      TSX:TSGI      15372.3  Consumer Discretionary                6113.9
# 119        TSX:TD    1334903.0              Financials              139949.9
# 120       TSX:TRI      23261.3             Industrials               43979.9
# 121         TSX:X      31657.9              Financials                5191.6
# 122       TSX:TIH       3234.5             Industrials                5103.1
# 123       TSX:TOU      10732.5                  Energy                4600.4
# 124       TSX:RNW       3747.0               Utilities                3727.1
# 125       TSX:VET       6270.7                  Energy                4419.2
# 126      NYSE:WCN      17230.5             Industrials               33303.5
# 127       TSX:WFT       4791.0               Materials                3758.8
# 128       TSX:WJA       6758.1             Industrials                3500.6
# 129       TSX:WPM       8828.6               Materials               14000.9
# 130       TSX:WSP       7766.6             Industrials                7728.9
# 131       TSX:YRI      10933.9               Materials                3268.9
#
#      NumberEmployees  TransactionType  TransactionValue
# 0             5990.0              4.0        401.837500
# 1            32600.0              1.0        200.000000
# 2             1700.0              2.0        170.055000
# 3             2277.0              6.0        495.600000
# 4           133000.0             10.0        848.108000
# 5              263.0              7.0        202.182857
# 6             2881.0              7.0        571.747143
# 7             6241.0              1.0        200.000000
# 8              967.0             14.0        106.191429
# 9             3168.0              NaN               NaN
# 10           45454.0            692.0        106.045882
# 11           17500.0              NaN               NaN
# 12           21100.0              9.0       1452.904444
# 13           52790.0              1.0        175.000000
# 14            3945.0              1.0        799.140000
# 15           56920.0              NaN               NaN
# 16            8568.0              NaN               NaN
# 17          101700.0              2.0        300.000000
# 18           26900.0              NaN               NaN
# 19            6000.0              NaN               NaN
# 20           19000.0              NaN               NaN
# 21            2325.0              NaN               NaN
# 22           12500.0              NaN               NaN
# 23           10000.0              1.0        732.800000
# 24            1897.0              NaN               NaN
# 25            3932.0              3.0        514.613333
# 26             908.0              4.0        212.630000
# 27           44797.0            532.0         98.546598
# 28           27215.0              9.0        579.946667
# 29            9973.0              7.0        976.471429
# ..               ...              ...               ...
# 102          16800.0              5.0        310.126000
# 103          10000.0              5.0        324.674000
# 104           4000.0              4.0        604.657500
# 105            337.0              7.0        221.495714
# 106          52435.0              5.0        435.014000
# 107           1881.0              3.0        143.193333
# 108          22000.0              1.0        525.140000
# 109           2108.0              3.0        260.513333
# 110          22318.0              3.0        582.663333
# 111          12480.0              6.0       1366.460000
# 112           7081.0              6.0       1670.153333
# 113          10000.0              2.0        810.665000
# 114          58000.0              5.0        734.074000
# 115          17636.0              NaN               NaN
# 116          99678.0            447.0        169.419150
# 117           1356.0              NaN               NaN
# 118           4516.0              3.0        972.600000
# 119          87999.0            252.0        333.375516
# 120          25800.0              4.0       1299.902500
# 121           1280.0              2.0        250.000000
# 122           6000.0              1.0        500.000000
# 123            237.0              5.0        209.916000
# 124              NaN              2.0        282.515000
# 125            698.0              1.0        402.200000
# 126          16356.0             12.0        198.457500
# 127           7800.0              1.0        525.180000
# 128          11905.0              2.0        299.185000
# 129             39.0              1.0        713.300000
# 130          49000.0              NaN               NaN
# 131           5165.0              1.0        385.610000
#
# [132 rows x 7 columns]

# %%
'''
- 2. Check the count, range, mean, median and standard deviation of each variable.
Does everything look relatively reasonable?
'''
SPTSX_Frame.describe()
# relatively
# Out:
#         TotalAssets  MarketCapitalization  NumberEmployees  TransactionType  \
# count  1.320000e+02            132.000000       131.000000       104.000000
# mean   7.979332e+04          18312.697727     22503.961832        39.403846
# std    2.181632e+05          24231.385466     39361.642805       161.807840
# min    2.611000e+02           3025.900000        34.000000         1.000000
# 25%    5.077725e+03           4753.875000      2135.000000         2.000000
# 50%    1.169030e+04           8977.600000      8568.000000         4.000000
# 75%    3.518675e+04          20034.375000     22159.000000         6.000000
# max    1.334903e+06         149713.500000    207000.000000      1257.000000
#
#        TransactionValue
# count        104.000000
# mean         529.486451
# std          440.358085
# min           10.190000
# 25%          211.951500
# 50%          402.018750
# 75%          730.260227
# max         2700.940000

# %%
'''
- 3. Identify any rows/observations containing NaN or null values. 
Handle them as you see fit. Hint: If a company does not appear in the transactions dataset, 
it is because it closed no transactions during the relevant time period. 
'''
SPTSX_Frame.isna().any()
# Out:
# Ticker                  False
# TotalAssets             False
# PrimarySector           False
# MarketCapitalization    False
# NumberEmployees          True
# TransactionType          True
# TransactionValue         True
# dtype: bool

# %%
'''
NumberEmployees, TransactionType(Total Number Transaction), TransactionValue
(average transaction value) have null values.
Let's deal with NumberEmployees first.
'''

SPTSX_Frame.loc[SPTSX_Frame.NumberEmployees.isna()]
# Out:
#       Ticker  TotalAssets PrimarySector  MarketCapitalization  \
# 124  TSX:RNW       3747.0     Utilities                3727.1
#
#      NumberEmployees  TransactionType  TransactionValue
# 124              NaN              2.0           282.515

# %%
# at this point, only TSX:RNW has NaN employees. Set it to at least 1.
# No company has 0 employees
# SPTSX_Frame['NumberEmployees']['TSX:RNW'] = 1
#SPTSX_Frame = SPTSX_Frame.drop(columns=('TSX:RNW', 'NumberEmployees'))
#SPTSX_Frame.loc[SPTSX_Frame.NumberEmployees.isna()]
#print(SPTSX_Frame.columns)
# SPTSX_Frame.set_index or for loc the first value has to be labeled index (iloc - int index)
SPTSX_Frame.loc[124, 'NumberEmployees'] = 1
# or, df.loc[df['column_name'] == some_value]
# print(SPTSX_Frame.index)
SPTSX_Frame.loc[SPTSX_Frame.NumberEmployees.isna()] # no NaN employees
# Out:
# Empty DataFrame
# Columns: [Ticker, TotalAssets, PrimarySector, MarketCapitalization, NumberEmployees, TransactionType, TransactionValue]
# Index: []

# %%
'''
TransactionType(Total Number Transaction), TransactionValue(average transaction value) 
have null values.
Let's deal with TransactionType next.
'''
SPTSX_Frame.loc[SPTSX_Frame.TransactionType.isna()]
# Out:
#            Ticker  TotalAssets           PrimarySector  MarketCapitalization  \
# 9         TSX:BTO       3476.6               Materials                4105.6
# 11        TSX:ABX      30880.9               Materials               37685.1
# 15      TSX:BBD.B      34056.2             Industrials                5233.7
# 16     TSX:BYD.UN       1233.5             Industrials                3473.0
# 18       NYSE:BBU      37276.5             Industrials                7560.6
# 19       NYSE:BIP      49914.9               Utilities               16419.9
# 20   NasdaqGS:BPY     167183.4             Real Estate               10333.7
# 21     TSX:BEP.UN      46534.9               Utilities               14574.3
# 22        TSX:DOO       3077.2  Consumer Discretionary                4689.0
# 24        TSX:CCO       8018.6                  Energy                5723.2
# 32         TSX:CU      21819.0               Utilities                9934.8
# 37      TSX:GIB.A      11919.1  Information Technology               27388.1
# 41        TSX:CCA       7167.4  Communication Services                5079.6
# 42       TSX:CIGI       3217.0             Real Estate                3777.6
# 43        TSX:CSU       4005.5  Information Technology               26390.4
# 46        TSX:DOL       2177.9  Consumer Discretionary               15624.1
# 49      TSX:EMP.A       9602.4        Consumer Staples                9112.5
# 56        TSX:FSV       1374.7             Real Estate                4914.9
# 60         TSX:WN      43814.0        Consumer Staples               15523.3
# 77        TSX:LUN       8098.2               Materials                5163.8
# 86       TSX:ONEX      61973.3              Financials                8135.8
# 88       TSX:PAAS       2643.8               Materials                3565.0
# 89        TSX:PXT       2356.5                  Energy                3129.7
# 96      TSX:QBR.B       9531.6  Communication Services                8096.2
# 97       NYSE:QSR      27483.2  Consumer Discretionary               24044.9
# 115      TSX:TFII       4050.0             Industrials                3241.5
# 117       TSX:DSG        858.9  Information Technology                4015.2
# 130       TSX:WSP       7766.6             Industrials                7728.9
#
#      NumberEmployees  TransactionType  TransactionValue
# 9             3168.0              NaN               NaN
# 11           17500.0              NaN               NaN
# 15           56920.0              NaN               NaN
# 16            8568.0              NaN               NaN
# 18           26900.0              NaN               NaN
# 19            6000.0              NaN               NaN
# 20           19000.0              NaN               NaN
# 21            2325.0              NaN               NaN
# 22           12500.0              NaN               NaN
# 24            1897.0              NaN               NaN
# 32            4919.0              NaN               NaN
# 37           77500.0              NaN               NaN
# 41            4574.0              NaN               NaN
# 42           13927.0              NaN               NaN
# 43           19000.0              NaN               NaN
# 46           14230.0              NaN               NaN
# 49          123000.0              NaN               NaN
# 56           20000.0              NaN               NaN
# 60          203238.0              NaN               NaN
# 77            3347.0              NaN               NaN
# 86          207000.0              NaN               NaN
# 88            4530.0              NaN               NaN
# 89             279.0              NaN               NaN
# 96           10039.0              NaN               NaN
# 97            6000.0              NaN               NaN
# 115          17636.0              NaN               NaN
# 117           1356.0              NaN               NaN
# 130          49000.0              NaN               NaN

# %%
# for transactiontype (Total number transactions), fill in 0
# SPTSX_Frame = SPTSX_Frame.fillna(value=0)
SPTSX_Frame = SPTSX_Frame.dropna() # remove the rows
SPTSX_Frame.loc[SPTSX_Frame.TransactionType.isna()]
#print(SPTSX_Frame.shape)
#TSX:BTO
#SPTSX_Frame.iloc[77]
SPTSX_Frame.isna().any()
print(SPTSX_Frame.shape)
# Out:
# (104, 7)

# %%
'''
- 4. Consider the histogram of Market Capitalization. What does it tell you? 
'''
SPTSX_Frame.MarketCapitalization.plot.hist(bins=60)
# right-skewed - most companies have less than 20000 employees

# %%
'''
- 5. Explore the relationships between Market Capitalization and the other variables
using scatter plots 
'''
# Market Capitalization vs Employee Count
SPTSX_Frame.plot.scatter('MarketCapitalization', 'NumberEmployees')
plt.title('Market Capitalization vs Number of Employees') # interfaces with matplotlib
plt.show()

# %%
# Market Capitalization vs Number of Transactions
SPTSX_Frame.plot.scatter('MarketCapitalization', 'TransactionType')
plt.title('Market Capitalization vs Number of Transactions')
plt.show()

# %%
# Market Capitalization vs Average Transaction Value
SPTSX_Frame.plot.scatter('MarketCapitalization', 'TransactionValue')
plt.title('Market Capitalization vs Average Transaction Value')
plt.show()

# %%
# Market Capitalization vs Total Assets
SPTSX_Frame.plot.scatter('MarketCapitalization', 'TotalAssets')
plt.title('Market Capitalization vs Total Assets')
plt.show()

# %%
'''
- 6. Look up another way or other ways to analyze/understand your data visually and
create the relevant plot using matplotlib or seaborn. 
(Suggestions: Boxplot, violin plot, correlation heatmap.)
'''
import seaborn as sns

# %%
sns.set(style="whitegrid")
SPTSX_BoxPlot = sns.boxplot(x=SPTSX_Frame["MarketCapitalization"])

# %%
SPTSX_ViolinPlot = sns.violinplot(x=SPTSX_Frame["MarketCapitalization"])

# %%
corr = SPTSX_Frame.corr()
SPTSX_Heatmap = sns.heatmap(corr)

# %%
# - 7. Answer the question, "how does market capitalization differ by sector?" 

SPTSX_Frame.groupby('PrimarySector')["MarketCapitalization"].mean()
# Out:
# PrimarySector
# Communication Services    24408.916667
# Consumer Discretionary    11106.477778
# Consumer Staples          16463.387500
# Energy                    22578.944444
# Financials                37278.333333
# Health Care                8944.120000
# Industrials               16617.676471
# Information Technology    20556.733333
# Materials                 11299.700000
# Real Estate                5828.336364
# Utilities                 10043.641667
# Name: MarketCapitalization, dtype: float64

# %%
'''
- 8. Save the cleaned DataFrame as a csv or excel file (df.to_csv(path)
or df.to_excel(path)). (Create a new directory for your outputs/reports)
'''
SPTSX_Frame.to_csv('SPTSX_Frame_csv_folder/SPTSX_Frame.csv')
